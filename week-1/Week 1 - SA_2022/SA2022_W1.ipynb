# %% [markdown]
# # SUMMER ANALYTICS 2022

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# # **Gotta catch 'em all !**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2022! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about Pokemons.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
ls
# Out:
# SA2022_W1.ipynb*  SA2022_W1_Pokemon.csv*

# %%
#your code here
df = pd.read_csv('SA2022_W1_Pokemon.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (800, 13)

# %%
#your code here
df.shape
# Out:
# (800, 13)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### 5) Remove the column '#' and update the dataframe.

# %%
#your code here
df.drop('#',axis=1,inplace=True)

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### 6) Set the 'Name' column as the index of dataframe

# %%
#your code here
df.set_index('Name',inplace=True)
df.head()
# Out:
#                       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %% [markdown]
# ###  7) Print a list of all the unique Type-1 powers

# %%
#your code here
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df['Type 1'].fillna('',inplace=True)
df['Type 2'].fillna('', inplace=True)

# %% [markdown]
# ### 8) Create a column which contains the Type 1 and Type 2 abilities of pokemons, seperated with a '+'' sign. Also, display the no. of pokemons that have type-1 power as 'Psychic' and type 2 power as 'Flying' using this new column.

# %%
def combine(type1, type2):
    return "{} + {}".format(type1, type2 )

# %%
#your code here

df["abilities"] = np.vectorize(combine)(df['Type 1'] , df['Type 2'])
df.head()
# Out:
#                       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# Charmander              Fire            309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary       abilities
# Name
# Bulbasaur                   65     45           1      False  Grass + Poison
# Ivysaur                     80     60           1      False  Grass + Poison
# Venusaur                   100     80           1      False  Grass + Poison
# VenusaurMega Venusaur      120     80           1      False  Grass + Poison
# Charmander                  50     65           1      False         Fire +

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. How many pokemons have 'Mega' in their name?

# %%
#your code here

def find_mega(name):
    return "Mega" in name

# %%
np.vectorize(find_mega)(df.index).sum()
# Out:
# 49

# %% [markdown]
# ### 2. What is the standard deviation of Sp. Def. in the dataset ?

# %%
#your code here
df['Sp. Def'].std()
# Out:
# 27.82891579711746

# %% [markdown]
# ### 3. What percentage (upto 3 decimal places) of pokemons are legendary ?

# %%
df['Legendary'].sum()
# Out:
# 65

# %%
#your code here
(df['Legendary'].sum())/ (df['Legendary'].shape[0])
# Out:
# 0.08125

# %% [markdown]
# ### 4. Name the pokemon(s) with Maximum Defense.

# %%
#your code here
df[df['Defense'] == df["Defense"].max()]
# Out:
#                     Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# SteelixMega Steelix  Steel  Ground    610  75     125      230       55
# Shuckle                Bug    Rock    505  20      10      230       10
# AggronMega Aggron    Steel            630  70     140      230       60
#
#                      Sp. Def  Speed  Generation  Legendary       abilities
# Name
# SteelixMega Steelix       95     30           2      False  Steel + Ground
# Shuckle                  230      5           2      False      Bug + Rock
# AggronMega Aggron         80     50           3      False        Steel +

# %% [markdown]
# ### 5. Which poison pokemon has the strongest attack ?

# %%
def find_in_column(search,str):
    return search in str

# %%
np.vectorize(find_in_column)("Poison",df['abilities']).sum()
# Out:
# 62

# %% [markdown]
# #### Psychic+Flying

# %%
df[df['abilities'] == "Psychic + Flying"]
# Out:
#            Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Natu      Psychic  Flying    320   40      50       45       70       45
# Xatu      Psychic  Flying    470   65      75       70       95       70
# Lugia     Psychic  Flying    680  106      90      130       90      154
# Woobat    Psychic  Flying    313   55      45       43       55       43
# Swoobat   Psychic  Flying    425   67      57       55       77       55
# Sigilyph  Psychic  Flying    490   72      58       80      103       80
#
#           Speed  Generation  Legendary         abilities
# Name
# Natu         70           2      False  Psychic + Flying
# Xatu         95           2      False  Psychic + Flying
# Lugia       110           2       True  Psychic + Flying
# Woobat       72           5      False  Psychic + Flying
# Swoobat     114           5      False  Psychic + Flying
# Sigilyph     97           5      False  Psychic + Flying

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, Bulbasaur to Volcanion
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Type 1      800 non-null    object
#  1   Type 2      800 non-null    object
#  2   Total       800 non-null    int64
#  3   HP          800 non-null    int64
#  4   Attack      800 non-null    int64
#  5   Defense     800 non-null    int64
#  6   Sp. Atk     800 non-null    int64
#  7   Sp. Def     800 non-null    int64
#  8   Speed       800 non-null    int64
#  9   Generation  800 non-null    int64
#  10  Legendary   800 non-null    bool
#  11  abilities   800 non-null    object
# dtypes: bool(1), int64(8), object(3)
# memory usage: 75.8+ KB

# %% [markdown]
# ### 6. Using seaborn make different types of plots, observe the trend and answer the questions given in the form.

# %%
#your code here
plt.figure(figsize=(6,4),dpi=150)
sns.histplot(data=df,x='Generation',hue='Legendary')
# Out:
# <AxesSubplot:xlabel='Generation', ylabel='Count'>

# %%
#your code here
plt.figure(figsize=(14,6),dpi=150)
sns.histplot(data=df,x='Type 1')
plt.title("Type 1")
# Out:
# Text(0.5, 1.0, 'Type 1')

# %%
#your code here
plt.figure(figsize=(14,6),dpi=150)
sns.histplot(data=df,x=df['Type 2'],color='skyblue',label="Type-2")
sns.histplot(data=df,x=df['Type 1'],color='pink',label="Type-1")
plt.legend()
plt.title("Type 2")
# Out:
# Text(0.5, 1.0, 'Type 2')

# %% [markdown]
# ### 7. Which is the second fastest non-legendary 'Ghost' type pokemon from 4th generation ?

# %%
#your code here
df[(np.vectorize(find_in_column)("Ghost",df['abilities'])) & (df['Generation']==4) & (np.invert(df['Legendary']))].sort_values("Speed",ascending=False)
# Out:
#              Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Froslass        Ice   Ghost    480   70      80       70       80       70
# Mismagius     Ghost            495   60      60       60      105      105
# Rotom      Electric   Ghost    440   50      50       77       95       77
# Drifblim      Ghost  Flying    498  150      80       44       90       54
# Drifloon      Ghost  Flying    348   90      50       34       60       44
# Dusknoir      Ghost            525   45     100      135       65      135
# Spiritomb     Ghost    Dark    485   50      92      108       92      108
#
#            Speed  Generation  Legendary         abilities
# Name
# Froslass     110           4      False       Ice + Ghost
# Mismagius    105           4      False          Ghost +
# Rotom         91           4      False  Electric + Ghost
# Drifblim      80           4      False    Ghost + Flying
# Drifloon      70           4      False    Ghost + Flying
# ...

# %% [markdown]
# ### 8. How many non-legendary pokemons have stronger defence but weaker attack than Charizard?

# %%
#your code here
inequality_calculated = df[(df["Defense"] > df.loc["Charizard"]["Defense"])  & (df["Attack"] < df.loc["Charizard"]["Attack"])]
inequality_calculated
# Out:
#                      Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Venusaur              Grass  Poison    525  80      82       83      100
# Wartortle             Water            405  59      63       80       65
# Blastoise             Water            530  79      83      100       85
# PidgeotMega Pidgeot  Normal  Flying    579  83      80       80      135
# Sandshrew            Ground            300  50      75       85       20
# ...                     ...     ...    ...  ..     ...      ...      ...
# Clawitzer             Water            500  71      73       88      120
# Carbink                Rock   Fairy    500  50      50      150       50
# Klefki                Steel   Fairy    470  57      80       91       80
# Bergmite                Ice            304  55      69       85       32
# Noivern              Flying  Dragon    535  85      70       80       97
#
#                      Sp. Def  Speed  Generation  Legendary        abilities
# Name
# ...

# %%
inequality_calculated[inequality_calculated["Legendary"] == False]
# Out:
#                      Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Venusaur              Grass  Poison    525  80      82       83      100
# Wartortle             Water            405  59      63       80       65
# Blastoise             Water            530  79      83      100       85
# PidgeotMega Pidgeot  Normal  Flying    579  83      80       80      135
# Sandshrew            Ground            300  50      75       85       20
# ...                     ...     ...    ...  ..     ...      ...      ...
# Clawitzer             Water            500  71      73       88      120
# Carbink                Rock   Fairy    500  50      50      150       50
# Klefki                Steel   Fairy    470  57      80       91       80
# Bergmite                Ice            304  55      69       85       32
# Noivern              Flying  Dragon    535  85      70       80       97
#
#                      Sp. Def  Speed  Generation  Legendary        abilities
# Name
# ...

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, here are some bonus questions that you can try to further deepen your understanding of the topic!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Which pokemon has the highest combined value of Attack and Sp. Atk ?

# %%
#your code here
(df['Attack'] + df['Sp. Atk']).sort_values(ascending=False)
# Out:
# Name
# DeoxysAttack Forme       360
# RayquazaMega Rayquaza    360
# MewtwoMega Mewtwo X      344
# MewtwoMega Mewtwo Y      344
# KyogrePrimal Kyogre      330
#                         ...
# Marill                    40
# Feebas                    25
# Magikarp                  25
# Shuckle                   20
# Happiny                   20
# Length: 800, dtype: int64

# %% [markdown]
# ### Which type of legendary pokemons are the most common?

# %%
#your code here
# question not clear

# %% [markdown]
# ### How many generation-3, non-legendary pokemons have higher HP than the weakest generation-6, legendary pokemon?

# %%
#your code here
((df[(df['Generation']==3) & (np.invert(df['Legendary']))  ]['HP']) > (df[ (df['Generation']==6) & (df['Legendary'])]['HP'].min())).sum()
# Out:
# 95

# %% [markdown]
# ### Print out the third slowest pokemon(s) in the dataset.

# %%
#your code here
df[df['Speed'] == df.sort_values('Speed')['Speed'].unique()[2]]
# Out:
#             Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Slowpoke     Water  Psychic    315  90      65       65       40       40
# Cleffa       Fairy             218  50      25       28       45       55
# Igglybuff   Normal    Fairy    210  90      30       15       40       20
# Wooper       Water   Ground    210  55      45       45       25       25
# Pineco         Bug             290  50      65       90       35       35
# Silcoon        Bug             205  50      35       55       25       25
# Cascoon        Bug             205  50      35       55       25       25
# Roggenrola    Rock             280  55      75       85       25       25
# Foongus      Grass   Poison    294  69      55       45       55       55
#
#             Speed  Generation  Legendary        abilities
# Name
# Slowpoke       15           1      False  Water + Psychic
# Cleffa         15           2      False         Fairy +
# ...

# %% [markdown]
# ### Which pokemon type has the highest average HP?

# %%
#your code here
